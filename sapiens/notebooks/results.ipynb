# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/1.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=1)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/2.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=1)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/3.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=1,top_n=10)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/4.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=10)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/5.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=5)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/6.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=5)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/7.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=5)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/8.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=0)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/9.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=0)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = 'trn'
res = cb.Result.from_file("../logs/4/10.log").filter_fin(l=L,p=['pid','rng'],)
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=1,top_n=20)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = 'trn'
res = cb.Result.from_file("../logs/4/11.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=1)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/12.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=6)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/13.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10,top_n=3)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/14.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10)
# Out:
# We removed 1 ['pid', 'rng'] because it did not exist for every ['evaluator_id', 's1', 's2', 's3', 'dae', 'ws', 'pers', 'y', 'trn', 'n_models', 'weighted'].

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/15.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/16.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/17.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10)

# %%
import matplotlib.pyplot as plt
import coba as cb
L = ['evaluator_id','s1','s2','s3','dae','ws','pers','y','trn','n_models','weighted']
res = cb.Result.from_file("../logs/4/18.log").filter_fin(l=L,p=['pid','rng'])
res.plot_learners('index','auc0',l=L,p=['pid','rng'],span=10)
