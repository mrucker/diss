# %%
import coba as cb
out1.plot_learners(xlim=(100,None),labels=['LinUCB','2 Layer Resnet', '2 Layer MLP'])
# Out:
# We removed 12 environment_id because they did not exist for every full_name.

# %%
#out0 = cb.Result.from_file('networks.log.gz')
out1 = cb.Result.from_file('networks2.log.gz')
out1
# Out:
# {'Learners': 3, 'Environments': 247, 'Interactions': 912000}

# %%
ids = set(out1.filter_fin(l='learner_id',p='environment_id').environments['openml_task'])

# %%
out0.where(openml_task=ids).where(learner_id=0).plot_learners(xlim=(100,None))

# %%
out0.where(openml_task=ids).plot_learners(xlim=(100,None),top_n=3)

# %%
out0.plot_learners(xlim=(100,None),top_n=3)

# %%
out1.where(learner_id=[1,2]).plot_learners(xlim=(100,None))

# %%
import coba as cb
cb.Result.from_file('networks2.log.gz')
# Out:
# {'Learners': 3, 'Environments': 247, 'Interactions': 820000}

# %%
cb.Result.from_file('networks2.log.gz')
# Out:
# {'Learners': 3, 'Environments': 247, 'Interactions': 904000}
